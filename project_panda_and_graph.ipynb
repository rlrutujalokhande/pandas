# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic=sns.load_dataset('titanic')         #seaborn dataframe 
titanic.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
titanic.isnull().count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            891
# sibsp          891
# parch          891
# fare           891
# embarked       891
# class          891
# who            891
# adult_male     891
# deck           891
# embark_town    891
# alive          891
# alone          891
# dtype: int64

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.nsmallest(10,'age')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# ...

# %%
titanic.nlargest(10,'age')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# 672         0       2  male  70.0      0      0  10.5000        S  Second
# 745         0       1  male  70.0      1      1  71.0000        S   First
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 54          0       1  male  65.0      0      1  61.9792        C   First
# 280         0       3  male  65.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# 630  man        True    A  Southampton   yes   True
# ...

# %%
titanic.memory_usage()
# Out:
# Index           128
# survived       7128
# pclass         7128
# sex            7128
# age            7128
# sibsp          7128
# parch          7128
# fare           7128
# embarked       7128
# class          1023
# who            7128
# adult_male      891
# deck           1247
# embark_town    7128
# alive          7128
# alone           891
# dtype: int64

# %%
titanic.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 106         1       3  female  21.0      0      0  7.65        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 106  woman       False  NaN  Southampton   yes   True

# %%
titanic.query("age>18")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Syntax of pandas.DataFrame.fillna()
# #DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None downcast=None)
titanic['deck'].fillna(np.nan)
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(({
     'Courses':["Spark",'Java',"Scala",'Python'],
     'Fee' :[20000,np.nan,26000,24000],
     'Duration':['30days','40days',np.nan,'40days'],
     'Discount':[1000,np.nan,2500,None]
               }))
print(df)
# Out:
#   Courses      Fee Duration  Discount
# 0   Spark  20000.0   30days    1000.0
# 1    Java      NaN   40days       NaN
# 2   Scala  26000.0      NaN    2500.0
# 3  Python  24000.0   40days       NaN

# %%
# fillna() on all columns
df2=df.fillna('None')
print(df2)
# Out:
#   Courses      Fee Duration Discount
# 0   Spark  20000.0   30days   1000.0
# 1    Java     None   40days     None
# 2   Scala  26000.0     None   2500.0
# 3  Python  24000.0   40days     None

# %%
titanic.sort_values("deck")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 96          0       1    male  71.0      0      0  34.6542        C   First
# 174         0       1    male  56.0      0      0  30.6958        C   First
# 209         1       1    male  40.0      0      0  31.0000        C   First
# 445         1       1    male   4.0      0      2  81.8583        S   First
# 647         1       1    male  56.0      0      0  35.5000        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sort_values("class")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 445         1       1    male   4.0      0      2   81.8583        S  First
# 310         1       1  female  24.0      0      0   83.1583        C  First
# 309         1       1  female  30.0      0      0   56.9292        C  First
# 307         1       1  female  17.0      1      0  108.9000        C  First
# 306         1       1  female   NaN      0      0  110.8833        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 379         0       3    male  19.0      0      0    7.7750        S  Third
# 381         1       3  female   1.0      0      2   15.7417        C  Third
# 382         0       3    male  32.0      0      0    7.9250        S  Third
# 371         0       3    male  18.0      1      0    6.4958        S  Third
# 890         0       3    male  32.0      0      0    7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.value_counts("embark_town")               #df.value_counts()
#This function returns — how many times a value appeared in a column. So, you need to pass the specific column name to this function
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# dtype: int64

# %%
df1 = titanic.iloc[0:10, :].copy()
  #df.copy()
#This is useful in copying the entire DataFrame in one go. It contains only one optional parameter, which you probably never need to use.

# %%
df1
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df1 = titanic.iloc[0:10,2:7].copy()
df1
# Out:
#       sex   age  sibsp  parch     fare
# 0    male  22.0      1      0   7.2500
# 1  female  38.0      1      0  71.2833
# 2  female  26.0      0      0   7.9250
# 3  female  35.0      1      0  53.1000
# 4    male  35.0      0      0   8.0500
# 5    male   NaN      0      0   8.4583
# 6    male  54.0      0      0  51.8625
# 7    male   2.0      3      1  21.0750
# 8  female  27.0      0      2  11.1333
# 9  female  14.0      1      0  30.0708

# %%
#df.rename()
#This is the simplest method to easily change the selected column name.
# all you need to do is pass a dictionary where the key is the old column name and the value is the new column name.

df1.rename(columns = {"age": "AGE","fare":"Charges"},inplace=True)
df1
# Out:
#       sex   AGE  sibsp  parch  Charges
# 0    male  22.0      1      0   7.2500
# 1  female  38.0      1      0  71.2833
# 2  female  26.0      0      0   7.9250
# 3  female  35.0      1      0  53.1000
# 4    male  35.0      0      0   8.0500
# 5    male   NaN      0      0   8.4583
# 6    male  54.0      0      0  51.8625
# 7    male   2.0      3      1  21.0750
# 8  female  27.0      0      2  11.1333
# 9  female  14.0      1      0  30.0708

# %%
#df.where()
#This function checks the DataFrame for a given condition and replaces values at all the locations with NaN where the condition is False.

condition = titanic["class"] == "First"
titanic.where(condition)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833        C  First
# 2         NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S  First
# 4         NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886       NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S  First
# 888       NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C  First
# 890       NaN     NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN
#
#        who adult_male deck  embark_town alive  alone
# ...

# %%
df1.drop('AGE',axis=1)  #However, to remove it forever, you need to make inplace=True in df.drop()
# Out:
#       sex  sibsp  parch  Charges
# 0    male      1      0   7.2500
# 1  female      1      0  71.2833
# 2  female      0      0   7.9250
# 3  female      1      0  53.1000
# 4    male      0      0   8.0500
# 5    male      0      0   8.4583
# 6    male      0      0  51.8625
# 7    male      3      1  21.0750
# 8  female      0      2  11.1333
# 9  female      1      0  30.0708

# %%
#df.corr()
#This method is used to find out pairwise correlations between all the columns of the DataFrame.
#So, when you do not mention any specific column names, it returns Pearson correlation coefficients for all the column pairs in the datasets.

titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
titanic[["fare","age"]].corr()
# Out:
#           fare       age
# fare  1.000000  0.096067
# age   0.096067  1.000000

# %%
#rolling() Key Points:

#It supports to calculate rolling mean, average, max, min, sum, count, median, std e.t.c
#By default it uses window type as None and provides a way to change it.
#It suports to specify minimum periods.

# %%
rolling=df1.rolling(window=2)
print(rolling)
# Out:
# Rolling [window=2,center=False,axis=0,method=single]

# %%
# Rolling() of sum with window length 3
df2=df1.rolling(window=3).sum()
print(df2)
# Out:
#     AGE  sibsp  parch   Charges
# 0   NaN    NaN    NaN       NaN
# 1   NaN    NaN    NaN       NaN
# 2  86.0    2.0    0.0   86.4583
# 3  99.0    2.0    0.0  132.3083
# 4  96.0    1.0    0.0   69.0750
# 5   NaN    1.0    0.0   69.6083
# 6   NaN    0.0    0.0   68.3708
# 7   NaN    3.0    1.0   81.3958
# 8  83.0    3.0    3.0   84.0708
# 9  43.0    4.0    3.0   62.2791

# %%
# Rolling() of mean with window length 3
df2=df1.rolling(window=3).mean()
print(df2)
# Out:
#          AGE     sibsp     parch    Charges
# 0        NaN       NaN       NaN        NaN
# 1        NaN       NaN       NaN        NaN
# 2  28.666667  0.666667  0.000000  28.819433
# 3  33.000000  0.666667  0.000000  44.102767
# 4  32.000000  0.333333  0.000000  23.025000
# 5        NaN  0.333333  0.000000  23.202767
# 6        NaN  0.000000  0.000000  22.790267
# 7        NaN  1.000000  0.333333  27.131933
# 8  27.666667  1.000000  1.000000  28.023600
# 9  14.333333  1.333333  1.000000  20.759700

# %%
#pandas MultiIndex Key Points –

#MultiIndex is an array of tuples where each tuple is unique.
##You can create MultiIndex from list of arrays, arry of tuples, dataframe e.t.c
#The Index constructor will attempt to return a MultiIndex when it is passed a list of tuples.
#You can have Multi-level for both Index and Column labels.
#Multi-level columns are used when you wanted to group columns together.

# %%
import pandas as pd
# Create Row Level MultiIndex 
new_index = pd.MultiIndex.from_tuples([("r0", "rA"),
                                       ("r1", "rB")],
                                       names=['indx1','indx2'])

# Create Column Level MultiIndex 
cols = pd.MultiIndex.from_tuples([("Gasoline", "Toyoto"), 
                                  ("Gasoline", "Ford"), 
                                  ("Electric", "Tesla"),
                                  ("Electric", "Nio")])

# Create MultiIndex DataFrame
data=[[100,300, 900,400 ], [200,500, 300,600]]
df = pd.DataFrame(data, columns=cols,index=new_index)
print('df= ',df)

# Convert MultiIndex to Columns
df2=df.reset_index()
print('df2= ',df2)

# Convert MuliIndex to Single index
df2 = df.reset_index(level=[1])
print('df2= ',df2)

# Drop Index
df2 = df.reset_index(level=[1], drop=True)
print('df2= ',df2)

# Flattern MultiIndex columns
df.columns = df.columns.get_level_values(1)
print('df=',df)

#Drop Index from MultiIndex
df=df.droplevel(0, axis=0) 
print('df= ',df)
# Out:
# df=              Gasoline      Electric
#               Toyoto Ford    Tesla  Nio
# indx1 indx2
# r0    rA         100  300      900  400
# r1    rB         200  500      300  600
# df2=    indx1 indx2 Gasoline      Electric
#                 Toyoto Ford    Tesla  Nio
# 0    r0    rA      100  300      900  400
# 1    r1    rB      200  500      300  600
# df2=        indx2 Gasoline      Electric
#               Toyoto Ford    Tesla  Nio
# indx1
# r0       rA      100  300      900  400
# r1       rB      200  500      300  600
# df2=        Gasoline      Electric
#         Toyoto Ford    Tesla  Nio
# indx1
# r0         100  300      900  400
# r1         200  500      300  600
# df=              Toyoto  Ford  Tesla  Nio
# indx1 indx2
# r0    rA        100   300    900  400
# r1    rB        200   500    300  600
# df=         Toyoto  Ford  Tesla  Nio
# indx2
# rA        100   300    900  400
# rB        200   500    300  600

# %%
df1 = titanic.iloc[0:10,2:7].copy()

# %% [markdown]
# **PLOT**

# %%
df1.plot(kind="bar")    #barplot
# Out:
# <Axes: >

# %%
from pandas.plotting import scatter_matrix    #scatter_matrix

scatter_matrix(df1, alpha=0.2, figsize=(6, 6), diagonal="kde")
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='sibsp', ylabel='age'>,
#         <Axes: xlabel='parch', ylabel='age'>,
#         <Axes: xlabel='fare', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='sibsp'>,
#         <Axes: xlabel='sibsp', ylabel='sibsp'>,
#         <Axes: xlabel='parch', ylabel='sibsp'>,
#         <Axes: xlabel='fare', ylabel='sibsp'>],
#        [<Axes: xlabel='age', ylabel='parch'>,
#         <Axes: xlabel='sibsp', ylabel='parch'>,
#         <Axes: xlabel='parch', ylabel='parch'>,
#         <Axes: xlabel='fare', ylabel='parch'>],
#        [<Axes: xlabel='age', ylabel='fare'>,
#         <Axes: xlabel='sibsp', ylabel='fare'>,
#         <Axes: xlabel='parch', ylabel='fare'>,
#         <Axes: xlabel='fare', ylabel='fare'>]], dtype=object)

# %%
sns.relplot(x='age',y='survived',data=titanic)    #replot

# %%
sns.relplot(x='age',y='sex',data=titanic,color='y')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.relplot(x='age',y='fare',data=titanic,kind='line')   #line relplot

# %%
sns.lineplot(x='age',y='fare',data=titanic)    #lineplot
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#distribution plot

sns.distplot(titanic['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.distplot(titanic['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic['age'],hist=True,kde=False,color='g')   # distpot is combination of histogram and lineplot
# Out:
# <Axes: xlabel='age'>

# %%
sns.jointplot(x='age',y='fare',data=titanic,kind='hist')      #joinplot

# %%
sns.jointplot(x='age',y='fare',data=titanic,kind='kde')

# %%
sns.pairplot(titanic)       #pairplot = this give relation betn columns

# %%
df1 = titanic.iloc[0:10,2:7].copy()
df1
sns.boxplot(x='age',y='fare',data=df1)       #boxplot
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(x='age',y='sex',data=df1)
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.violinplot(x='age',y='fare',data=df1)        #violinplot
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.regplot(x='age',y='fare',data=df1)    #regression plot
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.regplot(x='age',y='fare',data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.heatmap(titanic.corr())    #heatmap
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='fare',y='age',data=titanic)     #scatterpolt
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.catplot(x='fare',y='age',data=titanic)   #catplot

# %%
sns.barplot(x='fare',y='age',data=df1)    #barplot
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.stripplot(x='fare',y='age',data=titanic,hue='sex')    #stipplot
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
ages = titanic["age"]
AGE=ages.head(5)

# %%
plt.pie(AGE,labels=AGE)    #piechart
plt.show()
